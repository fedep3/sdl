# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import pyflux as pf

from readers.mat_reader import MatReader

mat_reader = MatReader('ColdComplaintData/Training')
ts, xs, ys = mat_reader.read()

new_xs = []
for i in xrange(len(xs)):
    new_x = [n for n in xs[i]]
    new_x.append(ys[i])
    new_xs.append(new_x)

df = pd.DataFrame(new_xs, index=ts, columns=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'temperature'])
df.describe()
# Out:
#                   A             B             C             D             E  \
# count  23038.000000  23038.000000  23038.000000  23038.000000  23038.000000
# mean       0.374381      0.878360      0.374425     13.194829     47.092493
# std        0.483973      1.823038      0.483985     32.964582     47.805952
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.406054
# 50%        0.000000      0.000000      0.000000      0.165894     18.212570
# 75%        1.000000      0.000000      1.000000      0.650654     99.515549
# max        1.000000      5.000000      1.000000    100.000000    100.000000
#
#                   F             G             H             I   temperature
# count  23038.000000  23038.000000  23038.000000  23038.000000  23038.000000
# mean    2099.842802     72.939277     47.994835   8067.364615     71.873907
# std      366.570054      2.213582      6.517545   3798.305667      1.610268
# min     1592.306519     66.869362     30.000000      0.000000     68.163109
# 25%     1861.378662     71.481857     43.000000   9999.000000     71.138741
# 50%     1910.776977     72.632172     49.000000   9999.000000     71.436867
# 75%     2453.584107     74.522171     53.500000   9999.000000     72.443733
# max     3057.181641     78.763420     59.000000  10001.000000     77.202484

# %%
df = pd.DataFrame(ys, index=ts, columns=['temperature'])
df.plot(figsize=(16, 12))

# %%
c = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']

for i in range(len(xs[0])):
    new_xs = []

    for j in xrange(len(xs)):
        new_x = [xs[j][i]]
        new_xs.append(new_x)

    df = pd.DataFrame(new_xs, index=ts, columns=[c[i]])
    df.plot(figsize=(16, 12))
